# %% [markdown]
# ### Třetí úkol
# bude pro prodejce doplnit hodnotu ve sloupci web vyextrovanou ze sloupce email pokud ji nemají uvedenou v příslušném formátu www.mujweb.fr. O rozhodnutí doplnění dané adresy prosím použijte četnostní kriterium, pokud je daných webových adres větší než nějaké množství. Např. pro orange.fr tak nemá smysl doplňovat adresu webu neboť se jedná o lokálního zřizovatele schránek podobně jako gmail.com nebo seznam.cz.

# %%
import pandas as pd
from collections import Counter
from typing import Any, Dict

# %% [markdown]
# Reading csv file and store it as pandas dataframe

# %%
df = pd.read_csv('dealers.csv')

# %% [markdown]
# Cast `email` column to a string type

# %%
df['email'] = df['email'].astype('str')

# %% [markdown]
# Creating subdataframe just with `web` and `email` columns

# %%
df_email = df[['web', 'email']]
# df_email.head(20)
# Out:
#                             web                              email
# 0                           NaN                                nan
# 1                           NaN               filippo@vadilonga.it
# 2                           NaN    cycleschedaleuxcaudan@gmail.com
# 3     www.cyclexperts-brest.com      contact@cyclexperts-brest.com
# 4                           NaN          cycles.chabbert@orange.fr
# 5             www.intersport.fr  cycle-epagny@reseau-intersport.fr
# 6                           NaN                lucadezzo@libero.it
# 7                           NaN             plestancycle@orange.fr
# 8                           NaN                contact@becycles.fr
# 9                           NaN                                nan
# 10        www.giant-dijon.fr/fr          cyclesdegueurce@orange.fr
# 11                          NaN                                nan
# 12          www.velo-horizon.fr             nantes@velo-horizon.fr
# 13                          NaN                  info@parisbmx.com
# 14             www.alltricks.fr                                nan
# 15                          NaN      sport2000@gozzi-sport2000.com
# 16         www.cyclesmagasin.fr           anthony@cyclesmagasin.fr
# 17                          NaN                                nan
# 18                          NaN             bikeinfinity@libero.it
# 19  bordeaux-ouest@cyclable.com        bordeaux-ouest@cyclable.com

# %% [markdown]
# Convert all the emails to a list type for further iteration

# %%
list_of_emails = df['email'].to_list()
list_of_emails
# Out:
# ['nan',
#  'filippo@vadilonga.it',
#  'cycleschedaleuxcaudan@gmail.com',
#  'contact@cyclexperts-brest.com',
#  'cycles.chabbert@orange.fr',
#  'cycle-epagny@reseau-intersport.fr',
#  'lucadezzo@libero.it',
#  'plestancycle@orange.fr',
#  'contact@becycles.fr',
#  'nan',
#  'cyclesdegueurce@orange.fr',
#  'nan',
#  'nantes@velo-horizon.fr',
#  'info@parisbmx.com',
#  'nan',
#  'sport2000@gozzi-sport2000.com',
#  'anthony@cyclesmagasin.fr',
#  'nan',
#  'bikeinfinity@libero.it',
#  'bordeaux-ouest@cyclable.com',
#  'benjamin.perusin@wanadoo.fr',
#  'nan',
#  'frulli.nicola@gmail.com',
#  'bikemania@libero.it',
#  'nan',
#  'nan',
#  'intersportbrignoles@live.fr',
#  'nan',
#  'nan',
#  'ciclomillenniosrl@gmail.com',
#  'nan',
#  'info@bikerstree.com',
#  'c2jvelo@orange.fr',
#  'noemotobikesrl@gmail.com',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'contact@hossegorbike.com',
#  'nan',
#  'nan',
#  'info@bagnolibike.com',
#  '69lyon-nord@culturevelo.com',
#  'nan',
#  'contact@velosdelavalette.fr',
#  'info@dolomitibikeshop.com',
#  'nan',
#  'ebikeworld85@gmail.com',
#  'nan',
#  'nan',
#  'legnano@bicimania.it',
#  'nan',
#  'nan',
#  'nan',
#  '74sallanches@culturevelo.com',
#  'assistenza@bikeshopping.it',
#  'simplysrl.info@gmail.com',
#  'nan',
#  'info@bicisportshop.com',
#  'contact@giant-city-gap.fr',
#  'info@eurovelo.it',
#  'sportissimosrl@hotmail.it',
#  'infoagobike@gmail.com',
#  'info@ideabici.it',
#  'nan',
#  'bouchet.benoit0848@gmail.com',
#  'cycleworks@wanadoo.fr',
#  'info@evolbike.it',
#  'cycles20@wanadoo.fr',
#  'romainmondovelo@orange.fr',
#  'espacebike12@orange.fr',
#  'giuseppe@d-z.it',
#  'valence@ecox.fr',
#  'nan',
#  'info@morettibassano.it',
#  'nan',
#  'nan',
#  'nan',
#  'cad@nerim.net',
#  'labicicletteria@libero.it',
#  'nan',
#  'nan',
#  'besancon@loisibike.fr',
#  'bikehospitalbugnone@libero.it',
#  'summumbike@gmail.com',
#  'nan',
#  'contact@velozen.com',
#  'velo77.coulommiers@yahoo.com',
#  'ah.durand@solig.fr',
#  'brunolevent@aol.com',
#  'digitalshops@yahoo.it',
#  'arras@reseau-intersport.fr',
#  'cycles-aventure@orange.fr',
#  'contact@planete-cycles.com',
#  'murcia.david@neuf.fr',
#  'info@veloclic.com',
#  'nan',
#  'contact@lesvelosdelabaie.bzh',
#  'nan',
#  'nan',
#  '41romorantin@culturevelo.com',
#  'er-man.cicli@libero.it',
#  'nan',
#  'infoagobike@gmail.com',
#  'info@mavinbikeshop.it',
#  '30ales@culturevelo.com',
#  'cycleone@orange.fr',
#  'nan',
#  'tobike@tobike-nals.it',
#  'cycles.darnanville@wanadoo.fr',
#  'bmxgangster@laposte.net',
#  'nan',
#  '94bonneuil@culturevelo.com',
#  'info@dipabikestore.com',
#  'parigibike@live.it',
#  'cycles.gaborit@gmail.com',
#  'contact@giant-englos.fr',
#  '64pau@culturevelo.com',
#  'nan',
#  'compta@ovelo.fr',
#  'info@rh-racing.it',
#  'nan',
#  'nan',
#  'pavonesport@gmail.com',
#  'info@ciclicoste.it',
#  'nan',
#  'ozone.vttcycles@gmail.com',
#  'nan',
#  'cyclestillousatelier@orange.fr',
#  'info@speedybikestore.it',
#  'boutique.du.triathlon@wanadoo.fr',
#  'lollobike17@gmail.com',
#  'contact@apesud.com',
#  'b.pailly@gmail.com',
#  'g2roues@orange.fr',
#  'info@giannisport.it',
#  'nan',
#  'dzumac@orange.fr',
#  'perigord.cycles@wanadoo.fr',
#  'tech-bike-71@orange.fr',
#  'nan',
#  'losacco.giuseppe@tiscali.it',
#  'nan',
#  'glovalenti@hotmail.it',
#  'elodie@glissenordic.com',
#  'mondovelolemansud@orange.fr',
#  'contact@stormbicycle.fr',
#  'becyclette56@gmail.com',
#  'nan',
#  'nan',
#  'nan',
#  'cyclessportpassion@gmail.com',
#  'paris12@exox.fr',
#  'legnano@bicimania.it',
#  'infos@cycles-zanet.com',
#  'montpellier@ovelo.fr',
#  'nan',
#  'contact@veloelectriquefrance.fr',
#  'rent@vuerichservice.it',
#  'info@green-bike.it',
#  'trocbike@hotmail.fr',
#  'contact@velozen.com',
#  'cyclollier@gmail.com',
#  'nan',
#  'cycles.passieu@wanadoo.fr',
#  'info@tondisport.it',
#  'nan',
#  'nan',
#  'valenciennes@my-velo.fr',
#  'leadercycles06@wanadoo.fr',
#  'commerciale@bikersitaly.it',
#  'jrpemobility@orange.fr',
#  'nan',
#  'cambonn@wanadoo.fr',
#  'v_vergati@virgilio.it',
#  'nan',
#  'tophymoto@wanadoo.fr',
#  'nan',
#  'info@inbikevalsugana.it',
#  '74annecy@culturevelo.com',
#  'nan',
#  'nan',
#  'purvelo@bbox.fr',
#  'giantparis12@gmail.com',
#  'nan',
#  'sport.anet@socamaine.fr',
#  'mag.nsbike.72@sfr.fr',
#  'nan',
#  'velopassioncaraibe@wanadoo.fr',
#  'giant-saintremydeprovence@outlook.fr',
#  'j.vidal@probikeshop.fr',
#  'info@cyclingcenterlab.com',
#  'cycleplestan@orange.fr',
#  'technic.bike.quimper@orange.fr',
#  'lesvelosdevictor@gmail.com',
#  'lyon@cycles-blain.com',
#  'administratif@my-velo.fr',
#  'shop@bmx2day.com',
#  'nan',
#  'info@cussighbike.it',
#  'nan',
#  'merslesbains@reseau-intersport.fr',
#  'nan',
#  'bikestore@pffft.it',
#  's.g.traverso67@gmail.com',
#  'contedenis@libero.it',
#  'nan',
#  'amministrazione@bikeacademyshop.com',
#  'cherbourg@citibike.fr',
#  'olmo.genova@olmopaolo.com',
#  'nan',
#  'cycle.intersport.salaise@gmail.com',
#  'maximum1@orange.fr',
#  'espace.velos@orange.fr',
#  'maddmaxx@libero.it',
#  '83toulon@culturevelo.com',
#  'cyclespicart@wanadoo.fr',
#  'nan',
#  'nan',
#  'cyclesevasion14@orange.fr',
#  'nan',
#  'mail@tecnobike.info',
#  'nan',
#  'info@teknobikestore2.it',
#  'nan',
#  'stegarau87@yahoo.it',
#  'cyclesportpera@orange.fr',
#  'nan',
#  'nan',
#  'alticoopvelo@sfr.fr',
#  'info@hbzerobike.it',
#  'nan',
#  'chambery@ovelo.fr',
#  'saint-priest@cycles-blain.com',
#  'info@bandiziol.it',
#  'sourcing@bee-s.fr',
#  '42saintetienne@culturevelo.com',
#  '47agen@culturevelo.com',
#  'nan',
#  'reggiolo@ciclisoprani.it',
#  'esprit-bmx@orange.fr',
#  '91villebon@culturevelo.com',
#  'afiando@smartemotion.it',
#  'capsulecycle@orange.fr',
#  'nan',
#  'nan',
#  'boillatjoris@gmail.com',
#  'anne@groupe-prosport.com',
#  'ridesport@yahoo.fr',
#  'nan',
#  'info@monferrato.bike',
#  'nan',
#  'mondovelo.strasbourg@orange.fr;atelier.mdv67@gmail.com',
#  'lissone@bicimania.it',
#  'cyclespierreperrin@wanadoo.fr',
#  'sarl.saint-pourcycles@akeonet.com',
#  'velonaturel@orange.fr',
#  'danilo.palladino@ebikepassion.com',
#  'adrenalinebikes@hotmail.fr',
#  'nan',
#  'quimper@velozen.com',
#  'nan',
#  'mondovelo.stlangislesmortagne@gmail.com',
#  'ope-amiensnord@groupe-prosport.com',
#  's-chauvot@groupe-villebenoit.fr',
#  'ericmenard@we-cycle.fr',
#  'nan',
#  'nan',
#  'saintbrieuc@velogiant.fr',
#  'atelierduvelo@gmail.com',
#  'nan',
#  'bikepluslesangles@gmail.com',
#  'nan',
#  'nantes.sud@ecox.fr',
#  'nan',
#  'info@ciclirossi.it',
#  'nan',
#  'nan',
#  'nan',
#  'bikesport.cesson@gmail.com',
#  'stefano@bikeservicetn.it',
#  'cycloavigliana@gmail.com',
#  'velo@gozzi-sport2000.com',
#  'nan',
#  'nan',
#  'denis@velo-horizon.fr',
#  'bikestore.firenze@gmail.com',
#  'nan',
#  'nan',
#  'contact@morelsport.com',
#  'fancellociclisport@gmail.com',
#  'annecy@cyclable.com',
#  'nan',
#  'fabien@brosstore.fr;robin@brosstore.fr',
#  'nan',
#  'nan',
#  'cyclesaixperts@gmail.com',
#  'nan',
#  'directeur-creil@groupe-prosport.com',
#  'international@materiel-velo.com',
#  'nan',
#  'nan',
#  'comptabilite@expercycle-feutrier.fr',
#  'patrickberaud@hotmail.fr',
#  'nan',
#  'marie-claude.besse2@wanadoo.fr',
#  'info@maniabike.eu',
#  '100cyclesphil@gmail.com',
#  'balto67@alice.it',
#  '07soyons@culturevelo.com',
#  'nextbikeshop@gmail.com',
#  'jf.barta@orange.fr',
#  'bike.garage@yahoo.it',
#  'nan',
#  'nan',
#  'd.viglietti@vigliettisport.com',
#  'nan',
#  'aubrac-electro-velo@orange.fr',
#  'nan',
#  'merolagroup@gmail.com',
#  'nan',
#  'nicola@ncridetech.com',
#  'napolibike@gmail.com',
#  'nan',
#  '01ferney-voltaire@bouticycle.com',
#  'shop@lovbike.it',
#  'nan',
#  'nan',
#  'contact@cycles-triquet.fr',
#  'kevin.lerich@gmail.com',
#  'nan',
#  'msa.arabba@gmail.com',
#  'contact@cityzen-bike.com',
#  'nan',
#  'gdf64tortoreto@gmail.com',
#  'nan',
#  'mondovelo.beziers@orange.fr',
#  'nan',
#  'slalanne@cycleslalanne.eu',
#  'nan',
#  'nan',
#  'cicliperacchi@gmail.com',
#  'remibenedetto@yahoo.fr',
#  'fratello@lesvelosdefratello.com',
#  'info@cicliboscaro.it',
#  'nan',
#  'sourcing@bee-s.fr',
#  'jadercyclesservices@gmail.com',
#  'nan',
#  'contact@funsportscycles.com',
#  'nan',
#  'info@unikacycling.it',
#  'nan',
#  'annecy@alpinbike.fr',
#  'nan',
#  'laiguillage@ecox.fr',
#  'energievelo@gmail.com',
#  'contact@beecyclette.fr',
#  'info@oliverobikes.it',
#  'nan',
#  'm.crusson@reseau-intersport.fr',
#  'nan',
#  'gestion@hymybike.com',
#  '2sp-moto@libero.it',
#  'contact@loisicycle.fr',
#  'pianetabici@libero.it',
#  'gthomas@cycles-thomas.com',
#  'nan',
#  'megacycles02000@wanadoo.fr',
#  'telemarkskihire@gmail.com',
#  'gbikeshop@gmail.com',
#  'rennes-montgermont@cyclable.com',
#  'nan',
#  'lamalsevizisrl@gmail.com',
#  'la.cyclerie@wanadoo.fr',
#  'leveloch@gmail.com',
#  'nan',
#  'antonella.girardi68@gmail.com',
#  'a.maxentsport@gmail.com',
#  'nan',
#  'bluebikes@wanadoo.fr',
#  'rennes@cyclable.com',
#  'info@veloseine.fr',
#  'nan',
#  'nan',
#  'lasquadra@la-squadra.cat',
#  'boyer.blanzy@wanadoo.fr',
#  'nan',
#  'nan',
#  'contact@velozen.com',
#  'mondovelosalon@orange.fr',
#  'anger@velo-horizon.fr',
#  'cicligaichieri@gmail.com',
#  'nan',
#  'contact@quaidescycles.fr',
#  'info@mazzante.it',
#  'f.chevignon@reseau-intersport.fr',
#  'info@ciclofficinaerrante.it',
#  'vanni@ciclidemurtas.it',
#  'cycle.huetvalhuisne@wanadoo.fr',
#  'nan',
#  'montpellier@cyclable.com',
#  '33bouliac@culturevelo.com',
#  'nan',
#  'contact@bmxavenue.com;fafa@bmxavenue.com',
#  'nan',
#  'nan',
#  'avranches@wareega.com',
#  'nan',
#  'info@veloactif.com',
#  'moutnbike@hotmail.fr',
#  'info@teamzola.it',
#  'xtrabike52@orange.fr',
#  'info@mikitours.it',
#  'velo02chateauthierry@gmail.com',
#  '59vdascq@culturevelo.com',
#  'robion@stationsbees.com',
#  'gregdemon@mondovelo-romans.fr',
#  '69pierrebenite@bouticycle.com',
#  'montpellier@ovelo.fr',
#  'ajpcycles@gmail.com',
#  'contact@atelierducycle.fr',
#  'tassin@velonaute.com',
#  'phiconte@orange.fr',
#  'specialiste-velos@hotmail.fr',
#  'pradal.sports@wanadoo.fr',
#  'info@3rdgen-shop.com',
#  'nicolas.houart@scarmor.fr',
#  'nan',
#  'info@dieffebike.com',
#  'nan',
#  'nan',
#  'info@newbike.it',
#  'info@ciclidalzilio.com',
#  'nan',
#  'nan',
#  'vienne@rhonavelo.fr',
#  'nan',
#  'nan',
#  'nan',
#  'cycloplanetpolicoro@gmail.com',
#  'nan',
#  'guillaumeneff@live.fr',
#  'fabrice@rouenbike.fr',
#  'info@ciclipasquini.it',
#  'bikemr@hotmail.it',
#  'nan',
#  'info@labici.it',
#  'gocycle@orange.fr',
#  'nan',
#  'info@parcobici.it',
#  'francheville@ecox.fr',
#  'celebikesas@gmail.com',
#  'info@cicliferca.com',
#  'nan',
#  'nan',
#  'cycles.berry@wanadoo.fr',
#  'caprio1906srl@gmail.com',
#  'cycles.fosse@wanadoo.fr',
#  'nan',
#  'nan',
#  'info@sinalungamotors.it',
#  'info@ciclibacchetti.com',
#  'info@leonardiracing.it',
#  'ledsportsbike@gmail.com',
#  '60chambly@culturevelo.com',
#  'marchiennes@my-velo.fr',
#  'nan',
#  'luca@tabosurf.com',
#  'cosentinocarmelo@live.it',
#  'giantstoreaubagne@gmail.com',
#  'info@skiarmin.com',
#  'rossiduerrecicli@gmail.com',
#  'info@happybikeonline.it',
#  'contact@jmc-cycles.fr',
#  'nan',
#  'funwaybike@hotmail.fr',
#  'mondovelolemansnord72@orange.fr',
#  'vire@cornerbike.fr',
#  'nan',
#  'giantm2mcb@gmail.com',
#  'l.neukirch@reseau-intersport.fr',
#  'info@motoracesarnico.it',
#  'marie-laure.rot@groupe-prosport.com',
#  'veloride.net@gmail.com',
#  'ltdv81@gmail.com',
#  'nan',
#  'nan',
#  'parisest@ecox.fr',
#  'rentacar60@club-internet.fr',
#  'giantstorepornic@orange.fr',
#  'brignais@cycles-blain.com',
#  'info@ciclighesla.com',
#  'info@bike-point.com',
#  'nan',
#  'cycles-du-bout-du-monde@orange.fr',
#  'julienchardon55@gmail.com',
#  'ifacquet@groupe-prosport.com',
#  'nan',
#  'contact@sportaixtrem.com',
#  'ciclorecord@virgilio.it',
#  'nan',
#  'cycles.maheau85@gmail.com',
#  'groupepriou@reseau-intersport.fr',
#  'caen@cornerbike.fr',
#  'nan',
#  'nice@ovelo.fr',
#  'labouilladisse@cycloplanet.com',
#  'nan',
#  'luca.b@sportler.com',
#  'runandbikeshop@gmail.com',
#  'nan',
#  'altisports43@orange.fr',
#  'nan',
#  'info@ciclissimo.it',
#  'sourcing@bee-s.fr',
#  'nan',
#  'nan',
#  'passion.velo@wanadoo.fr',
#  'nan',
#  'jeanchristophe.broggini@cyclable.com',
#  'veloandco@gmail.com',
#  'nan',
#  'nan',
#  'nan',
#  'villereal@stationsbees.com',
#  'nan',
#  'melissandre.sport2000@gmail.com',
#  'abicyclette71@gmail.com',
#  'contact@cycle-obsession.com',
#  'ciclimorbiato@gmail.com',
#  'emanuele@rushriders.cc',
#  'nan',
#  'nan',
#  'bruno.tollu@gmail.com',
#  'nan',
#  'teknobike99@tiscali.it',
#  'cyclesdelcayre@gmail.com',
#  'nan',
#  'nan',
#  'levantebike@gmail.com',
#  'info@nardis-sport.it',
#  'ssoussan@veloelectriquefrance.fr',
#  'grandisbike@gmail.com',
#  'nan',
#  'elementscycles@gmail.com',
#  'ajackson@acycles.fr',
#  'nan',
#  'velo1max@orange.fr',
#  'fouchycycles@wanadoo.fr',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'info@roadhousemotor.com',
#  'nan',
#  'energievelo@gmail.com',
#  'lorrainevsp@hotmail.fr',
#  'info@skiverleih-hofer.com',
#  'stephane@cybervelo.com',
#  'velo.mc2@gmail.com',
#  'nan',
#  'nan',
#  'gianttoulon@gmail.com',
#  'evolutionbikes@libero.it',
#  'funbike13@gmail.com',
#  'orcel3@wanadoo.fr',
#  'bicipaolo@virgilio.it',
#  'nan',
#  'g.campaner@giustasrl.com',
#  'ac.cycles@sfr.fr',
#  'sarl-jeangeneu@orange.fr',
#  'info@mtbschool.it',
#  'sport2000nort@hotmail.com',
#  'nan',
#  'culture.velo@cdv-bikes.com',
#  'nan',
#  'saint-etienne@cyclable.com',
#  'nan',
#  '76lehavre@culturevelo.com',
#  'nan',
#  'info@unikacycling.it',
#  'orleans@cyclable.com',
#  'velo77.coulommiers@yahoo.com',
#  'nan',
#  'nan',
#  'nan',
#  'thibaut.boutin@revedevelo.com',
#  'info@ski-vandel.com',
#  'info@ciclipesenti.it',
#  'titouvilleneuve@yahoo.fr',
#  'nicolas@greentrack.fr',
#  'cobranbike@gmail.com',
#  'contact@ovelo.fr',
#  'nan',
#  'cite2roues@hotmail.fr',
#  'contact@hurandteam.fr',
#  'bordeaux@cyclable.com',
#  'cycles7-p-arades@orange.fr',
#  'info@dueruotebike.it',
#  'nan',
#  'pouilly.evasion@orange.fr',
#  'steph.cycles@orange.fr',
#  'info@cyclingcenterlab.com',
#  'hbjlp06@gmail.com',
#  'nan',
#  'jeromecpz@gmail.com',
#  'contact@sportaixtrem.com',
#  'bike.sport.federico@gmail.com',
#  'directeur.noyelles@groupe-prosport.com',
#  'nan',
#  'florian.brureau@hotmail.fr',
#  'info@running330.it',
#  '51reims@culturevelo.com',
#  'sebpommier65@hotmail.fr',
#  'nan',
#  'info@bikepro.it',
#  'assbike@gmail.com',
#  'nan',
#  'wb3cycle@orange.fr',
#  'cyclesibanez@gmail.com',
#  'nan',
#  'nan',
#  'nan',
#  'rentacar60@club-internet.fr',
#  'ciclipapini@inwind.it',
#  'sebmoto@wanadoo.fr',
#  'nan',
#  'nan',
#  'info@campellocycling.it',
#  'centreparis2@zeride.fr',
#  'cycle-greau@orange.fr',
#  'info@sporteliteschool.com',
#  'nan',
#  'nan',
#  'carlos.dasilva@bernaudeaucycles.fr',
#  'ferdinardiello@libero.it',
#  'nan',
#  'nan',
#  'ateliervelo@orange.fr',
#  'pradal.sports@wanadoo.fr',
#  'nan',
#  'alexandre@lyoncyclechic.com',
#  'gk@rentandgo.it',
#  'batycycles@orange.fr',
#  'massimoknutti@gmail.com',
#  '54nancy@culturevelo.com',
#  'roudier.inspiration.cycles@gmail.com',
#  'c.allaire@groupe-hfv.fr',
#  'bordeaux@ovelo.fr',
#  'luca@clsglobal.it',
#  'fantoni.p@clxeurope.com;giacomo.fantoni@icloud.com',
#  'lou.pachran@gmail.com',
#  'giant.bastia@orange.fr',
#  'charlene@lvr-cycles.com',
#  'nan',
#  'nan',
#  'multicycles67390@gmail.com',
#  'info@magricycles.com',
#  'girelli.cicli@libero.it',
#  'francois_michel6@club-internet.fr',
#  'cotedazur@loisibike.fr',
#  'espacevelodrome@gmail.com',
#  'batinich@nerim.net',
#  'lagodille-sports@wanadoo.fr',
#  'biebisportsrl@libero.it',
#  'info@misterbicifabriano.it',
#  'migliobike@libero.it',
#  'info@lenzibike.it',
#  'nan',
#  'mybikes@icloud.com',
#  'nan',
#  'thibaut@cyrpeo.com',
#  'giant.rennesmontgermont@gmail.com',
#  'info@bikeshop-passeier.it',
#  'cyclesfauvel27@orange.fr',
#  'nan',
#  'mickael.b@agplus-sport.com',
#  'multimotorsmodica@gmail.com',
#  'breizhrandocycles@gmail.com',
#  'bestbike@live.it',
#  'montpellier@cycling.fr',
#  'cyclesattitude53@gmail.com',
#  'massimobike@hotmail.it',
#  'nan',
#  'nan',
#  'christian@bikeoclock.it',
#  'velo-styl@orange.fr',
#  'nan',
#  'nan',
#  'megacycles02000@wanadoo.fr',
#  'info@mega-bike.it',
#  'nan',
#  '07soyons@culturevelo.com',
#  'cassegrain.francis@wanadoo.fr',
#  'contact.cyclesoflife@gmail.com',
#  'intersport-stpere@reseau-intersport.fr',
#  'maurizio@spreaficocicli.it',
#  'annemasse@ovelo.fr',
#  'marielle.gamalai@wanadoo.fr',
#  'quadmotojuls@orange.fr',
#  'techno.bike07@gmail.com',
#  'direzione@ursusadventures.it',
#  'intersportbrive@yahoo.fr',
#  'techbike71@orange.fr',
#  'mfstefano@libero.it',
#  'info@veloclic.com',
#  'samsbike@cegetel.net',
#  'davide.corsini@cepgreen.com',
#  'info@pesarobici.com',
#  'nan',
#  'nan',
#  'nan',
#  'edarmigny@lmed-solutions.fr',
#  'cyclesbaie@gmail.com',
#  'nan',
#  'cycles.evasion85@orange.fr',
#  'nan',
#  'mg.cholet@reseau-intersport.fr',
#  'nan',
#  'nan',
#  'alessandro.damario@ciclismomarket.it',
#  'nan',
#  'nan',
#  'nan',
#  'info@larioebike.com',
#  'mimmo.bortone@gmail.com',
#  'nan',
#  'nan',
#  'emme2@hotmail.it',
#  'contact@lechappeebelle.bike',
#  'ciro@topbikerental.com',
#  'nan',
#  'adeloy@groupebrocal.com',
#  'nan',
#  'nan',
#  'comptamauguio@gmail.com',
#  'nan',
#  'seynod@madeinvelo.fr',
#  'advbiketorino@gmail.com',
#  'nan',
#  'sarlhcbk@gmail.com',
#  'citibikeaix@gmail.com',
#  'denochedaleux@gmail.com',
#  'nan',
#  'e.tramuta@gmail.com',
#  'ralfierbike@gmail.com',
#  'gj-bikes@hotmail.com',
#  'nan',
#  'sccentrobici@live.it',
#  '78rambouillet@culturevelo.com',
#  'nan',
#  'hubertcycles@gmail.com',
#  'nan',
#  'braincycles.cittadella@gmail.com',
#  'nan',
#  'nan',
#  'nan',
#  'info@campioli.it',
#  'nan',
#  'storo@savscorteagrarie.it',
#  'tama@wanadoo.fr',
#  'nan',
#  'tomicicli@gmail.com',
#  'info@huno.eu',
#  'giantmontlucon@gmail.com',
#  'nan',
#  'nan',
#  'co2bikepalermo@gmail.com',
#  'valence@ecox.fr',
#  'nan',
#  'sourcing@bee-s.fr',
#  'tassin@velonaute.com',
#  'info@sportazzurro.it',
#  'bertasisante.bici@alice.it',
#  'langueuxcycles@gmail.com',
#  'giantlibourne@orange.fr',
#  'nan',
#  'vianellibikes@hotmail.it',
#  'auxdeuxroues@nerim.net',
#  'lyon@ecox.fr',
#  'nan',
#  'ciclopoint@libero.it',
#  'info@traccebikes.com',
#  'nan',
#  'sarl-royer.remi@wanadoo.fr',
#  'commerciale@finisport.it',
#  'baskovelos@gmail.com',
#  'gipiemme.srl@tiscali.it',
#  'p.regimbeau@wanadoo.fr',
#  'info@ciclilucchini.com',
#  'culturevelopontault@orange.fr',
#  'nan',
#  'nan',
#  'sourcing@bee-s.fr',
#  'nan',
#  'info@estoremobility.it',
#  'jeanmichel.malo@live.fr',
#  'nan',
#  'romanet.sport.julien@gmail.com',
#  'cycles.pierre@wanadoo.fr',
#  'cycling.univers@outlook.fr',
#  'info@hubert-cycles.com',
#  'georges.deparseval@chullanka.com',
#  'gaillac@stationsbees.com',
#  'nan',
#  'lyon7@cyclable.com',
#  'veloocity64@orange.fr',
#  'bikenco@hotmail.fr',
#  'contact@snowleader.com',
#  'contact@alsacevelopassion.fr',
#  'tetedor@velonaute.com',
#  '974saint-denis@culturevelo.com',
#  'ebicisrl@libero.it',
#  'info@camperlike.it',
#  'cyclespedegaye.admin@orange.fr',
#  'nan',
#  'nan',
#  'nan',
#  '69lyon-ouest@culturevelo.com',
#  'noleggioandalo@gmail.com',
#  'mondovelo@sport2000-montmorot.com',
#  '365bikestore@gmail.com',
#  'maurienne-sport@wanadoo.fr',
#  'espacecycles@orange.fr',
#  'didier.barlet@storebike.fr',
#  'espacecycles53@gmail.com',
#  'info@ciclisumindario.it',
#  '128bikeavenue@orange.fr',
#  'cycles.bouyer@orange.fr',
#  '64anglet@culturevelo.com',
#  'elselena@cimone.it',
#  'francoboemio@virgilio.it',
#  'helies.kevin@gmail.com',
#  'vehrtsbleucompany@orange.fr',
#  'nan',
#  'info@marcellinsport.com',
#  'auveloelectrique@gmail.com',
#  'narcyvelo18@gmail.com',
#  'savin.jb@avredis.fr',
#  'distri-limoges@cegetel.net',
#  '47agen@culturevelo.com',
#  'nan',
#  'nan',
#  'la.cyclerie@wanadoo.fr',
#  'nan',
#  'magasin@tournon-cycles.fr',
#  'nan',
#  'lechappeeroannaise@gmail.com',
#  'morlescycle@gmail.com',
#  'mountain.cycles@orange.fr',
#  'jm.rigobert@wanadoo.fr',
#  'saintaff.bikeshop@gmail.com',
#  'kronossport@katamail.com',
#  'nan',
#  'annecy@cyclable.com',
#  'a.bozzi@savscorteagrarie.it',
#  'nan',
#  'ciaoguglielmo@live.it',
#  'info@ciclifatato.com',
#  'marvejolscyclesandco@orange.fr',
#  'nan',
#  'info@cgsnc.it',
#  'nan',
#  'info@nardello.it',
#  'nan',
#  'tourville@reseau-intersport.fr',
#  'contact@electric-cycles.fr',
#  'lannion.cycles@orange.fr',
#  'nan',
#  'nan',
#  'nan',
#  'cycle.ubaye.sports@gmail.com',
#  'mermoudsports@wanadoo.fr',
#  'mathieu.sport@orange.fr',
#  'sarles@lebiclou.fr',
#  'info@becchiscicli.it',
#  'marc.r@motoland.eu',
#  'alister.svitorka@e-bikeexpress.fr',
#  'bikestationfano@gmail.com',
#  'nan',
#  'nan',
#  'apicellacicli@libero.it',
#  'veloproshop@gmail.com',
#  'amministrazione@bikeacademyshop.com',
#  'veloshop0818@orange.fr',
#  'fabrice.pilard@wanadoo.fr',
#  'info@carismabike.it',
#  'sourcing@bee-s.fr',
#  'lpolve@gmail.com',
#  'info@bbbikeforli.it',
#  'cycle.embrun@reseau-intersport.fr',
#  'nan',
#  'contact@jmvcycles.fr',
#  'intersport.vaison@gmail.com',
#  'lissone@bicimania.it',
#  'nan',
#  '754.sb@reseau-intersport.fr',
#  'velosmagandrezieux@gmail.com',
#  'nan',
#  '31colomiers@culturevelo.com',
#  'nan',
#  'info@lamauro.it',
#  'fatture@sportlifee.com',
#  'nan',
#  'jeansport.2@wanadoo.fr',
#  'info@ebikeworldsrl.it',
#  'adherence44@gmail.com',
#  'contact.bicycool@gmail.com',
#  'ciclimontanini@gmail.com',
#  'info@veloservice.org',
#  'nan',
#  'nan',
#  'stefano@vuerichservice.it',
#  'fabrice.pilard@wanadoo.fr',
#  'nan',
#  'nan',
#  'nan',
#  'info@ridealone.it',
#  'bikegiuliani@gmail.com',
#  'robert.motta@tiscali.it',
#  'giant-thionville@orange.fr',
#  'contact@alpes-ride.com',
#  'info@ideabici.it',
#  'nan',
#  'sourcing@bee-s.fr',
#  '38allbike@gmail.com',
#  'tours@cyclable.com',
#  'nan',
#  'ciclirodas@gmail.com',
#  'ev.abbeville@gmail.com',
#  'info@criscionesport.it',
#  'jmt-sports@orange.fr',
#  'happybike@wanadoo.fr',
#  'contact@lesvelosdechailluz.com',
#  'nan',
#  'giantpuget@gmail.com',
#  'cicli.capobianchi@virgilio.it',
#  'royalcycle25@hotmail.com',
#  'tobike@tobike-nals.it',
#  'nan',
#  'nan',
#  'velo.oxygen83@gmail.com',
#  'caroline-tixier@dafy-moto.fr',
#  'goodmancycles@yahoo.fr',
#  'info@bikestationsarzana.com',
#  'info@labottegadelciclo.it',
#  'denis@velo-horizon.fr',
#  'nan',
#  '31blagnac@culturevelo.com',
#  'bernard.preuss@wanadoo.fr',
#  'cyclescums@orange.fr',
#  'cycle.stgilles@reseau-intersport.fr',
#  'ufficioacquisti@hitinero.com',
#  'negozio.bustoarsizio@mandelli.net',
#  'electrobike.caen@gmail.com',
#  'giant.anglet@orange.fr',
#  'info@mega-bike.it',
#  'info@bunnyhop.it',
#  'cicloosrl@gmail.com',
#  'nan',
#  'contact@cycle-elec.fr',
#  'nan',
#  'nan',
#  'cyclesduloir@orange.fr',
#  'c.trognon@exagonebike.com',
#  'info@cicliviviani.com',
#  'carole.guy@groupe-prosport.com',
#  'yannick.lagardere@cbogroup.fr',
#  'kevin.lerich@altermove.com',
#  'spano-fr.au@live.it',
#  'mondovelo.stalban@groupepvl.fr',
#  'nan',
#  'nan',
#  'ciclomaniavb@libero.it',
#  'caen@cornerbike.fr',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'info@ridextreme.it',
#  'thillois@reseau-intersport.fr',
#  'contact@revbikes.fr',
#  'brien.patrick@gmail.com',
#  '73albertville@culturevelo.com',
#  'contact@giantavignon.com',
#  'atelier@sun-e-bike.com',
#  'amantecasellasnc@gmail.com',
#  'nan',
#  'nordbikestore@gmail.com',
#  's.diakite@reseau-intersport.fr',
#  'boyer.cycles@wanadoo.fr',
#  'contact@mor-lescycles.com',
#  'contact@mondovelo-montauban.fr',
#  'gpbike.carbonia@gmail.com',
#  'nan',
#  'assistenza.bikers@carsam.it',
#  'cycles.chauviere@nerim.net',
#  'nan',
#  'fun.velo70@gmail.com',
#  ...]

# %%
def extract_domain(email: str) -> str:
    """
    Extracts the domain from an email address.

    Args:
        email (str): The email address 
        from which to extract the domain.

    Returns:
        str: The domain extracted from the email address, 
        or the original email if it is empty or 'nan'.

    """
    if email and email != 'nan':
        domain = email.split('@')[-1]
        return domain
    return email

# %% [markdown]
# List of extracted e-mail domains

# %%
extracted_domains = [extract_domain(email) for email in list_of_emails]
# extracted_domains

# %% [markdown]
# Frequency of e-mail domains

# %%
counter = Counter(extracted_domains)
email_freq = counter.most_common()

# %%
email_freq = dict(email_freq)

# %%
email_freq.pop('nan')
# Out:
# 1034

# %%
def should_fill_website(
    domain: str, 
    email_freq: Dict[str, int],
    threshold: int
) -> bool:
    """
    Determines whether the website should be filled 
    based on the frequency of the domain in email addresses.

    Args:
        domain (str): The domain for which to check the frequency.
        threshold (int): The threshold value for the frequency.
        email_freq (Dict[str, int]): A dictionary 
            mapping domains to their corresponding frequency.

    Returns:
        bool: True if the frequency of the domain is below the threshold, 
              False otherwise.

    """
    return email_freq.get(domain, 0) < threshold

# %%
def fill_website(row: pd.Series) -> pd.Series:
    """
    Fill the 'web' column in a DataFrame row 
    based on the 'email' column.

    If the 'web' column is empty or 'nan' 
    and the 'email' column is not empty, 
    it extracts the domain from the email
    and checks if it should fill the 'web' column 
    based on the frequency threshold.

    Args:
        row (pd.Series): A row from the DataFrame 
            containing the 'email' and 'web' columns.

    Returns:
        pd.Series: The modified row with the 'web' column filled if applicable.

    """
    email = row['email']
    web = row['web']
    
    if pd.isna(web) and email and email != 'nan':
        domain = extract_domain(email)
        if should_fill_website(domain, email_freq, threshold=100):
            row['web'] = f'www.{domain}'
    
    return row

# %%
df = df.apply(fill_website, axis=1)
df.head(20)
# Out:
#                                       id       brand  \
# 0   6105d615-25c7-49b8-b564-2b5801f5c156          gt
# 1   6441b601-37d9-4862-9a1e-3d47e8fcf12f       scott
# 2   9534c4c5-a68b-4d80-a0fc-6a98cd7f06b0    kalkhoff
# 3   850475e2-fe0a-493d-8d7c-95e6c608a17e       scott
# 4   989897bd-430a-412e-9f6e-0120b783c10c    superior
# 5   aa4df157-9987-4536-a119-b0349cf331f4       scott
# 6   af9dd896-a3c7-4000-b6a9-8de154b9d696     haibike
# 7   b1429343-1d39-42bc-b29b-2438f49136b1          gt
# 8   d954d861-06df-4685-8498-2c7d33c2e3d3     haibike
# 9   0983af7a-62a3-4435-aa6c-72a24091b9f9  cannondale
# 10  d0c8af1f-ad3f-4103-9492-3114991fa1c7    giantliv
# 11  c8000d0b-9f0c-498f-8a23-8edee9388ff9        trek
# 12  c18ea3b2-8fba-441a-9d7d-7aafc320f917         ktm
# 13  b29c8822-1335-4677-9ab9-f1da4fa9550d          gt
# 14  133b9000-39b0-4aef-9d7d-93faf2e4da2c          gt
# 15  f714b6e1-af68-4da7-9d53-c7c736223b44     haibike
# 16  4aec3ea4-61cf-4a3a-aa8d-10ac93e14964       focus
# 17  f672640b-ddaa-451c-bb4f-b9a0cb0fa7d9        trek
# 18  dfeed6e3-143f-444f-891f-164ecf068095       scott
# 19  da370fc7-6aa5-489e-98a3-e540e24257de    kalkhoff
#
#                                   eshop        lat        lng country  \
# 0            Vaunage Passion Velos Sarl  43.813962   4.348726  France
# 1                         VADILONGA SRL  39.251569   9.138519   Italy
# 2                SARL Cycles Charreteur  47.785181  -3.340796  France
# 3                     CYCLEXPERTS BREST  48.428370  -4.458959  France
# 4                       CYCLES CHABBERT  43.461200   3.422830  France
# 5                     INTERSPORT EPAGNY  45.934126   6.086538  France
# 6                       La Bici Volante  45.590835  11.522423   Italy
# 7                        PLESTAN CYCLES  48.465099  -2.510837  France
# 8                             BE CYCLES  45.766710   3.120810  France
# 9                               LordGun  45.524746  10.196167   Italy
# 10                        GIANT - DIJON  47.311867   5.052037  France
# 11  CICLI BONFANTI DI BRESCIANI ROBERTO  45.688589   9.662249   Italy
# 12                     SAS VELO CONTACT  47.222918  -1.639786  France
# 13                 PARIS BMX (BMX only)  48.857604   2.368488  France
# 14          Alltricks Store Issy les Mx  48.823486   2.273273  France
# 15                           SPORT 2000  45.368160   5.580470  France
# 16                           SAS Cycles  44.644523   4.377379  France
# 17                      MONACO BIKE PRO  43.733420   7.419172  France
# 18                    BIKE INFINITY SAS  43.916466   7.848784   Italy
# 19              Cyclable Bordeaux Ouest  44.832496  -0.641617  France
#
#                                               address  \
# 0               165 Av. Jean Prouvé, Nîmes, 30000, FR
# 1                    VIALE ELMAS 172, CAGLIARI, 09122
# 2       Rue Jean Baptiste Mertenot 330, Caudan, 56850
# 3             RUE ROSEMONDE GERARD 5, GOUESNOU, 29850
# 4                1 AVENUE FRNCOIS HUE, PEZENAS, 34120
# 5                    RUE DU PARMELAN 2, EPAGNY, 74330
# 6   Via Gardellina 28, 36030 Rettorgole di Caldogn...
# 7     28 RUE CHANTOINE DU TEMPLE, LAMBALLE, 22400, FR
# 8         267 RUE DE L ORADOU, 63000 CLERMONT-FERRAND
# 9                         Via Fura, 7, Brescia, 25125
# 10                121 RUE D AUXONNE, 21000 DIJON , 26
# 11             VIA PREVITALI 19 BERGAMO , 24127 Italy
# 12            360 BD Marcel Paul 44800 Saint Herblain
# 13                    47 rue Amelot, PARIS, 75011, FR
# 14  9 Rue Auguste Gervais, Issy les Moulineaux, 92...
# 15                 ZI LES BLANCHISSERIE, 38500 VOIRON
# 16                        74 Route de Vals Ucel 07200
# 17                 3 RUE LANGLE MONACO , 98000 France
# 18              VIA GIACOMO PUCCINI 3, IMPERIA, 18100
# 19            228 Avenue de la Marne, Mérignac, 33700
#
#                             web          telephone  \
# 0                           NaN          466361627
# 1              www.vadilonga.it       +39070240537
# 2                           NaN       +33297331790
# 3     www.cyclexperts-brest.com      +330298425857
# 4                           NaN     04.67.98.12.90
# 5             www.intersport.fr      +330450222822
# 6                 www.libero.it      +390444986265
# 7                           NaN      +330296341690
# 8               www.becycles.fr       +33473262624
# 9                           NaN         0303757092
# 10        www.giant-dijon.fr/fr       +33380651888
# 11                          NaN         0353054946
# 12          www.velo-horizon.fr   tel:+33240432576
# 13             www.parisbmx.com  +3309.54.62.99.07
# 14             www.alltricks.fr       +33130489007
# 15      www.gozzi-sport2000.com       +33476668990
# 16         www.cyclesmagasin.fr      +330678926346
# 17                          NaN      0037793252240
# 18                www.libero.it      +390183210708
# 19  bordeaux-ouest@cyclable.com      +330556991148
#
#                                 email
# 0                                 nan
# 1                filippo@vadilonga.it
# 2     cycleschedaleuxcaudan@gmail.com
# 3       contact@cyclexperts-brest.com
# 4           cycles.chabbert@orange.fr
# 5   cycle-epagny@reseau-intersport.fr
# 6                 lucadezzo@libero.it
# 7              plestancycle@orange.fr
# 8                 contact@becycles.fr
# 9                                 nan
# 10          cyclesdegueurce@orange.fr
# 11                                nan
# 12             nantes@velo-horizon.fr
# 13                  info@parisbmx.com
# 14                                nan
# 15      sport2000@gozzi-sport2000.com
# 16           anthony@cyclesmagasin.fr
# 17                                nan
# 18             bikeinfinity@libero.it
# 19        bordeaux-ouest@cyclable.com
